# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('./data/shoes.csv')

# %%
pd.set_option("display.max_columns",None)

# %%
data.head()
# Out:
#   category         subcategory  \
# 0    shoes             Loafers
# 1    shoes             Loafers
# 2    shoes             Loafers
# 3    shoes  Sneakers & Baskets
# 4    shoes             Loafers
#
#                                                 name  current_price  \
# 0  Chaussures décontractées antidérapantes en tis...          36.40
# 1  Chaussures en cuir à carreaux pour hommes de g...          46.36
# 2       Chaussures décontractées en cuir pour hommes          43.38
# 3     Baskets plates élastiques en tricot d'épissage          19.99
# 4  Hommes Cuir Épissage Soft Semelle Casual Chaus...          46.18
#
#    raw_price currency  discount  likes_count  is_new    brand  \
# 0      72.80      USD        50          873   False      NaN
# 1     106.49      USD        57          358   False      NaN
# 2     119.98      USD        64         1511   False   Menico
# 3      39.99      USD        50         1873   False      NaN
# 4     119.98      USD        62         2738   False      NaN
#
#                                         brand_url         codCountry  \
# 0                                             NaN  ID,MY,PH,SG,TH,VN
# 1                                             NaN  ID,MY,PH,SG,TH,VN
# 2  https://fr.newchic.com/-menico-brand-1716.html  ID,MY,PH,SG,TH,VN
# 3                                             NaN  ID,MY,PH,SG,TH,VN
# 4                                             NaN  ID,MY,PH,SG,TH,VN
#
#   variation_0_color variation_1_color  \
# 0             Black             Khaki
# 1               Red              Blue
# 2             Black             Khaki
# 3             Green              Blue
# 4              Bleu              Noir
#
#                                variation_0_thumbnail  \
# 0  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 1  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 2  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 3  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 4  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
#
#                                    variation_0_image  \
# 0  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 1  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 2  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 4  https://imgaz1.chiccdn.com/thumb/view/oaupload...
#
#                                variation_1_thumbnail  \
# 0  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 1  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 2  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 3  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 4  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
#
#                                    variation_1_image  \
# 0  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 1  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 2  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 4  https://imgaz1.chiccdn.com/thumb/view/oaupload...
#
#                                            image_url  \
# 0  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 1  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 2  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 4  https://imgaz1.chiccdn.com/thumb/view/oaupload...
#
#                                                  url       id      model
# 0   https://fr.newchic.com/flats-3616/p-1687903.html  1687903  SKUF29428
# 1   https://fr.newchic.com/flats-3616/p-1533324.html  1533324  SKUC99128
# 2  https://fr.newchic.com/-menico-flats-3616/p-16...  1651734  SKUE68011
# 3  https://fr.newchic.com/sneakersandathletic-359...  1591892  SKUD85085
# 4   https://fr.newchic.com/flats-3616/p-1474682.html  1474682  SKUC15622

# %%
data.shape
# Out:
# (11823, 22)

# %%
data['model'].unique().shape
# Out:
# (11764,)

# %%
data['subcategory'].unique()
# Out:
# array(['Loafers', 'Sneakers & Baskets', 'Boots & Ankle Boots', 'Baskets',
#        'Sandales', 'Ladies boots', nan, 'Slippers', 'High heels',
#        'Slipper', 'Town footwear', 'Footwear accessories',
#        'Flat & Loafers', 'Sports shoes'], dtype=object)

# %%
data.isnull().sum()
# Out:
# category                     0
# subcategory               1198
# name                         0
# current_price                0
# raw_price                    0
# currency                     0
# discount                     0
# likes_count                  0
# is_new                       0
# brand                    10348
# brand_url                10361
# codCountry                2559
# variation_0_color           45
# variation_1_color         1114
# variation_0_thumbnail       45
# variation_0_image           45
# variation_1_thumbnail     1114
# variation_1_image         1114
# image_url                    0
# url                          0
# id                           0
# model                        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11823 entries, 0 to 11822
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   category               11823 non-null  object
#  1   subcategory            10625 non-null  object
#  2   name                   11823 non-null  object
#  3   current_price          11823 non-null  float64
#  4   raw_price              11823 non-null  float64
#  5   currency               11823 non-null  object
#  6   discount               11823 non-null  int64
#  7   likes_count            11823 non-null  int64
#  8   is_new                 11823 non-null  bool
#  9   brand                  1475 non-null   object
#  10  brand_url              1462 non-null   object
#  11  codCountry             9264 non-null   object
#  12  variation_0_color      11778 non-null  object
#  13  variation_1_color      10709 non-null  object
#  14  variation_0_thumbnail  11778 non-null  object
#  15  variation_0_image      11778 non-null  object
#  16  variation_1_thumbnail  10709 non-null  object
#  17  variation_1_image      10709 non-null  object
#  18  image_url              11823 non-null  object
#  19  url                    11823 non-null  object
#  20  id                     11823 non-null  int64
#  21  model                  11823 non-null  object
# dtypes: bool(1), float64(2), int64(3), object(16)
# memory usage: 1.9+ MB

# %%
drop_cloumns = ['discount', 'currency', 'brand', 'brand_url', 'codCountry', 'variation_0_color', 'variation_1_color', 'variation_0_thumbnail', 'variation_0_image', 'variation_1_thumbnail', 'variation_1_image', 'image_url', 'model', 'url']

# %%
df = data.drop(drop_cloumns, axis=1)

# %%
df.head()
# Out:
#   category         subcategory  \
# 0    shoes             Loafers
# 1    shoes             Loafers
# 2    shoes             Loafers
# 3    shoes  Sneakers & Baskets
# 4    shoes             Loafers
#
#                                                 name  current_price  \
# 0  Chaussures décontractées antidérapantes en tis...          36.40
# 1  Chaussures en cuir à carreaux pour hommes de g...          46.36
# 2       Chaussures décontractées en cuir pour hommes          43.38
# 3     Baskets plates élastiques en tricot d'épissage          19.99
# 4  Hommes Cuir Épissage Soft Semelle Casual Chaus...          46.18
#
#    raw_price  likes_count  is_new       id
# 0      72.80          873   False  1687903
# 1     106.49          358   False  1533324
# 2     119.98         1511   False  1651734
# 3      39.99         1873   False  1591892
# 4     119.98         2738   False  1474682

# %%
df['subcategory'].unique()
# Out:
# array(['Loafers', 'Sneakers & Baskets', 'Boots & Ankle Boots', 'Baskets',
#        'Sandales', 'Ladies boots', nan, 'Slippers', 'High heels',
#        'Slipper', 'Town footwear', 'Footwear accessories',
#        'Flat & Loafers', 'Sports shoes'], dtype=object)

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#   category         subcategory  \
# 0    shoes             Loafers
# 1    shoes             Loafers
# 2    shoes             Loafers
# 3    shoes  Sneakers & Baskets
# 4    shoes             Loafers
#
#                                                 name  current_price  \
# 0  Chaussures décontractées antidérapantes en tis...          36.40
# 1  Chaussures en cuir à carreaux pour hommes de g...          46.36
# 2       Chaussures décontractées en cuir pour hommes          43.38
# 3     Baskets plates élastiques en tricot d'épissage          19.99
# 4  Hommes Cuir Épissage Soft Semelle Casual Chaus...          46.18
#
#    raw_price  likes_count  is_new       id
# 0      72.80          873   False  1687903
# 1     106.49          358   False  1533324
# 2     119.98         1511   False  1651734
# 3      39.99         1873   False  1591892
# 4     119.98         2738   False  1474682

# %%
df.shape
# Out:
# (10625, 8)

# %%
df.isnull().sum()
# Out:
# category         0
# subcategory      0
# name             0
# current_price    0
# raw_price        0
# likes_count      0
# is_new           0
# id               0
# dtype: int64

# %%
likes_features_df = df.pivot_table(index='name', columns='subcategory', values=['likes_count','current_price', 'is_new', 'raw_price']).fillna(0)
likes_features_df.to_csv('likes_features_df_women.csv', index=False)
likes_features_df.head()
# Out:
#                                                    current_price  \
# subcategory                                              Blazers
# name
#  Chemise boutonnée à col en forme de chat                    0.0
#  Chemise irrégulière oversize occasionnelle de ...           0.0
#  Chemisier ample imprimé sauvage simple boutonnage           0.0
#  Chemisier décontracté à manches longues et col...           0.0
#  Gradient Casual Sweat à manches longues pour l...           0.0
#
#                                                                        \
# subcategory                                        Blouses & Chemises
# name
#  Chemise boutonnée à col en forme de chat                       18.17
#  Chemise irrégulière oversize occasionnelle de ...              22.62
#  Chemisier ample imprimé sauvage simple boutonnage              22.62
#  Chemisier décontracté à manches longues et col...               0.00
#  Gradient Casual Sweat à manches longues pour l...               0.00
#
#                                                                            \
# subcategory                                        Chemises Denim & Jeans
# name
#  Chemise boutonnée à col en forme de chat              0.00           0.0
#  Chemise irrégulière oversize occasionnelle de ...     0.00           0.0
#  Chemisier ample imprimé sauvage simple boutonnage     0.00           0.0
#  Chemisier décontracté à manches longues et col...    31.99           0.0
#  Gradient Casual Sweat à manches longues pour l...     0.00           0.0
#
#                                                             \
# subcategory                                        Hoodies
# name
#  Chemise boutonnée à col en forme de chat              0.0
#  Chemise irrégulière oversize occasionnelle de ...     0.0
#  Chemisier ample imprimé sauvage simple boutonnage     0.0
#  Chemisier décontracté à manches longues et col...     0.0
#  Gradient Casual Sweat à manches longues pour l...    21.0
#
#                                                                           \
# subcategory                                        Hoodies & Sweatshirts
# name
#  Chemise boutonnée à col en forme de chat                            0.0
#  Chemise irrégulière oversize occasionnelle de ...                   0.0
#  Chemisier ample imprimé sauvage simple boutonnage                   0.0
#  Chemisier décontracté à manches longues et col...                   0.0
#  Gradient Casual Sweat à manches longues pour l...                   0.0
#
#                                                                                \
# subcategory                                        Jackets Leggings Nightgown
# name
#  Chemise boutonnée à col en forme de chat              0.0      0.0       0.0
#  Chemise irrégulière oversize occasionnelle de ...     0.0      0.0       0.0
#  Chemisier ample imprimé sauvage simple boutonnage     0.0      0.0       0.0
#  Chemisier décontracté à manches longues et col...     0.0      0.0       0.0
#  Gradient Casual Sweat à manches longues pour l...     0.0      0.0       0.0
#
#                                                                  \
# subcategory                                        Robes Shorts
# name
#  Chemise boutonnée à col en forme de chat            0.0    0.0
#  Chemise irrégulière oversize occasionnelle de ...   0.0    0.0
#  Chemisier ample imprimé sauvage simple boutonnage   0.0    0.0
#  Chemisier décontracté à manches longues et col...   0.0    0.0
#  Gradient Casual Sweat à manches longues pour l...   0.0    0.0
#
#                                                                     \
# subcategory                                        Suits & Co-ords
# name
#  Chemise boutonnée à col en forme de chat                      0.0
#  Chemise irrégulière oversize occasionnelle de ...             0.0
#  Chemisier ample imprimé sauvage simple boutonnage             0.0
#  Chemisier décontracté à manches longues et col...             0.0
#  Gradient Casual Sweat à manches longues pour l...             0.0
#
#                                                                              \
# subcategory                                        Sun Protective Outerwear
# name
#  Chemise boutonnée à col en forme de chat                               0.0
#  Chemise irrégulière oversize occasionnelle de ...                      0.0
#  Chemisier ample imprimé sauvage simple boutonnage                      0.0
#  Chemisier décontracté à manches longues et col...                      0.0
#  Gradient Casual Sweat à manches longues pour l...                      0.0
#
#                                                                            \
# subcategory                                        Sweatershirts T-shirts
# name
#  Chemise boutonnée à col en forme de chat                    0.0      0.0
#  Chemise irrégulière oversize occasionnelle de ...           0.0      0.0
#  Chemisier ample imprimé sauvage simple boutonnage           0.0      0.0
#  Chemisier décontracté à manches longues et col...           0.0      0.0
#  Gradient Casual Sweat à manches longues pour l...           0.0      0.0
#
#                                                               is_new  \
# subcategory                                        TOPS Tops Blazers
# name
#  Chemise boutonnée à col en forme de chat           0.0  0.0     0.0
#  Chemise irrégulière oversize occasionnelle de ...  0.0  0.0     0.0
#  Chemisier ample imprimé sauvage simple boutonnage  0.0  0.0     0.0
#  Chemisier décontracté à manches longues et col...  0.0  0.0     0.0
#  Gradient Casual Sweat à manches longues pour l...  0.0  0.0     0.0
#
#                                                                        \
# subcategory                                        Blouses & Chemises
# name
#  Chemise boutonnée à col en forme de chat                         0.0
#  Chemise irrégulière oversize occasionnelle de ...                0.0
#  Chemisier ample imprimé sauvage simple boutonnage                0.0
#  Chemisier décontracté à manches longues et col...                0.0
#  Gradient Casual Sweat à manches longues pour l...                0.0
#
#                                                                            \
# subcategory                                        Chemises Denim & Jeans
# name
#  Chemise boutonnée à col en forme de chat               0.0           0.0
#  Chemise irrégulière oversize occasionnelle de ...      0.0           0.0
#  Chemisier ample imprimé sauvage simple boutonnage      0.0           0.0
#  Chemisier décontracté à manches longues et col...      0.0           0.0
#  Gradient Casual Sweat à manches longues pour l...      0.0           0.0
#
#                                                             \
# subcategory                                        Hoodies
# name
#  Chemise boutonnée à col en forme de chat              0.0
#  Chemise irrégulière oversize occasionnelle de ...     0.0
#  Chemisier ample imprimé sauvage simple boutonnage     0.0
#  Chemisier décontracté à manches longues et col...     0.0
#  Gradient Casual Sweat à manches longues pour l...     0.0
#
#                                                                           \
# subcategory                                        Hoodies & Sweatshirts
# name
#  Chemise boutonnée à col en forme de chat                            0.0
#  Chemise irrégulière oversize occasionnelle de ...                   0.0
#  Chemisier ample imprimé sauvage simple boutonnage                   0.0
#  Chemisier décontracté à manches longues et col...                   0.0
#  Gradient Casual Sweat à manches longues pour l...                   0.0
#
#                                                                                \
# subcategory                                        Jackets Leggings Nightgown
# name
#  Chemise boutonnée à col en forme de chat              0.0      0.0       0.0
#  Chemise irrégulière oversize occasionnelle de ...     0.0      0.0       0.0
#  Chemisier ample imprimé sauvage simple boutonnage     0.0      0.0       0.0
#  Chemisier décontracté à manches longues et col...     0.0      0.0       0.0
#  Gradient Casual Sweat à manches longues pour l...     0.0      0.0       0.0
#
#                                                                  \
# subcategory                                        Robes Shorts
# name
#  Chemise boutonnée à col en forme de chat            0.0    0.0
#  Chemise irrégulière oversize occasionnelle de ...   0.0    0.0
#  Chemisier ample imprimé sauvage simple boutonnage   0.0    0.0
#  Chemisier décontracté à manches longues et col...   0.0    0.0
#  Gradient Casual Sweat à manches longues pour l...   0.0    0.0
#
#                                                                     \
# subcategory                                        Suits & Co-ords
# name
#  Chemise boutonnée à col en forme de chat                      0.0
#  Chemise irrégulière oversize occasionnelle de ...             0.0
#  Chemisier ample imprimé sauvage simple boutonnage             0.0
#  Chemisier décontracté à manches longues et col...             0.0
#  Gradient Casual Sweat à manches longues pour l...             0.0
#
#                                                                              \
# subcategory                                        Sun Protective Outerwear
# name
#  Chemise boutonnée à col en forme de chat                               0.0
#  Chemise irrégulière oversize occasionnelle de ...                      0.0
#  Chemisier ample imprimé sauvage simple boutonnage                      0.0
#  Chemisier décontracté à manches longues et col...                      0.0
#  Gradient Casual Sweat à manches longues pour l...                      0.0
#
#                                                                            \
# subcategory                                        Sweatershirts T-shirts
# name
#  Chemise boutonnée à col en forme de chat                    0.0      0.0
#  Chemise irrégulière oversize occasionnelle de ...           0.0      0.0
#  Chemisier ample imprimé sauvage simple boutonnage           0.0      0.0
#  Chemisier décontracté à manches longues et col...           0.0      0.0
#  Gradient Casual Sweat à manches longues pour l...           0.0      0.0
#
#                                                              likes_count  \
# subcategory                                        TOPS Tops     Blazers
# name
#  Chemise boutonnée à col en forme de chat           0.0  0.0         0.0
#  Chemise irrégulière oversize occasionnelle de ...  0.0  0.0         0.0
#  Chemisier ample imprimé sauvage simple boutonnage  0.0  0.0         0.0
#  Chemisier décontracté à manches longues et col...  0.0  0.0         0.0
#  Gradient Casual Sweat à manches longues pour l...  0.0  0.0         0.0
#
#                                                                        \
# subcategory                                        Blouses & Chemises
# name
#  Chemise boutonnée à col en forme de chat                       413.0
#  Chemise irrégulière oversize occasionnelle de ...               75.0
#  Chemisier ample imprimé sauvage simple boutonnage               38.0
#  Chemisier décontracté à manches longues et col...                0.0
#  Gradient Casual Sweat à manches longues pour l...                0.0
#
#                                                                            \
# subcategory                                        Chemises Denim & Jeans
# name
#  Chemise boutonnée à col en forme de chat               0.0           0.0
#  Chemise irrégulière oversize occasionnelle de ...      0.0           0.0
#  Chemisier ample imprimé sauvage simple boutonnage      0.0           0.0
#  Chemisier décontracté à manches longues et col...    402.0           0.0
#  Gradient Casual Sweat à manches longues pour l...      0.0           0.0
#
#                                                             \
# subcategory                                        Hoodies
# name
#  Chemise boutonnée à col en forme de chat              0.0
#  Chemise irrégulière oversize occasionnelle de ...     0.0
#  Chemisier ample imprimé sauvage simple boutonnage     0.0
#  Chemisier décontracté à manches longues et col...     0.0
#  Gradient Casual Sweat à manches longues pour l...    91.0
#
#                                                                           \
# subcategory                                        Hoodies & Sweatshirts
# name
#  Chemise boutonnée à col en forme de chat                            0.0
#  Chemise irrégulière oversize occasionnelle de ...                   0.0
#  Chemisier ample imprimé sauvage simple boutonnage                   0.0
#  Chemisier décontracté à manches longues et col...                   0.0
#  Gradient Casual Sweat à manches longues pour l...                   0.0
#
#                                                                                \
# subcategory                                        Jackets Leggings Nightgown
# name
#  Chemise boutonnée à col en forme de chat              0.0      0.0       0.0
#  Chemise irrégulière oversize occasionnelle de ...     0.0      0.0       0.0
#  Chemisier ample imprimé sauvage simple boutonnage     0.0      0.0       0.0
#  Chemisier décontracté à manches longues et col...     0.0      0.0       0.0
#  Gradient Casual Sweat à manches longues pour l...     0.0      0.0       0.0
#
#                                                                  \
# subcategory                                        Robes Shorts
# name
#  Chemise boutonnée à col en forme de chat            0.0    0.0
#  Chemise irrégulière oversize occasionnelle de ...   0.0    0.0
#  Chemisier ample imprimé sauvage simple boutonnage   0.0    0.0
#  Chemisier décontracté à manches longues et col...   0.0    0.0
#  Gradient Casual Sweat à manches longues pour l...   0.0    0.0
#
#                                                                     \
# subcategory                                        Suits & Co-ords
# name
#  Chemise boutonnée à col en forme de chat                      0.0
#  Chemise irrégulière oversize occasionnelle de ...             0.0
#  Chemisier ample imprimé sauvage simple boutonnage             0.0
#  Chemisier décontracté à manches longues et col...             0.0
#  Gradient Casual Sweat à manches longues pour l...             0.0
#
#                                                                              \
# subcategory                                        Sun Protective Outerwear
# name
#  Chemise boutonnée à col en forme de chat                               0.0
#  Chemise irrégulière oversize occasionnelle de ...                      0.0
#  Chemisier ample imprimé sauvage simple boutonnage                      0.0
#  Chemisier décontracté à manches longues et col...                      0.0
#  Gradient Casual Sweat à manches longues pour l...                      0.0
#
#                                                                            \
# subcategory                                        Sweatershirts T-shirts
# name
#  Chemise boutonnée à col en forme de chat                    0.0      0.0
#  Chemise irrégulière oversize occasionnelle de ...           0.0      0.0
#  Chemisier ample imprimé sauvage simple boutonnage           0.0      0.0
#  Chemisier décontracté à manches longues et col...           0.0      0.0
#  Gradient Casual Sweat à manches longues pour l...           0.0      0.0
#
#                                                              raw_price  \
# subcategory                                        TOPS Tops   Blazers
# name
#  Chemise boutonnée à col en forme de chat           0.0  0.0       0.0
#  Chemise irrégulière oversize occasionnelle de ...  0.0  0.0       0.0
#  Chemisier ample imprimé sauvage simple boutonnage  0.0  0.0       0.0
#  Chemisier décontracté à manches longues et col...  0.0  0.0       0.0
#  Gradient Casual Sweat à manches longues pour l...  0.0  0.0       0.0
#
#                                                                        \
# subcategory                                        Blouses & Chemises
# name
#  Chemise boutonnée à col en forme de chat                       35.62
#  Chemise irrégulière oversize occasionnelle de ...              55.43
#  Chemisier ample imprimé sauvage simple boutonnage              53.34
#  Chemisier décontracté à manches longues et col...               0.00
#  Gradient Casual Sweat à manches longues pour l...               0.00
#
#                                                                            \
# subcategory                                        Chemises Denim & Jeans
# name
#  Chemise boutonnée à col en forme de chat               0.0           0.0
#  Chemise irrégulière oversize occasionnelle de ...      0.0           0.0
#  Chemisier ample imprimé sauvage simple boutonnage      0.0           0.0
#  Chemisier décontracté à manches longues et col...     68.4           0.0
#  Gradient Casual Sweat à manches longues pour l...      0.0           0.0
#
#                                                             \
# subcategory                                        Hoodies
# name
#  Chemise boutonnée à col en forme de chat             0.00
#  Chemise irrégulière oversize occasionnelle de ...    0.00
#  Chemisier ample imprimé sauvage simple boutonnage    0.00
#  Chemisier décontracté à manches longues et col...    0.00
#  Gradient Casual Sweat à manches longues pour l...   51.47
#
#                                                                           \
# subcategory                                        Hoodies & Sweatshirts
# name
#  Chemise boutonnée à col en forme de chat                            0.0
#  Chemise irrégulière oversize occasionnelle de ...                   0.0
#  Chemisier ample imprimé sauvage simple boutonnage                   0.0
#  Chemisier décontracté à manches longues et col...                   0.0
#  Gradient Casual Sweat à manches longues pour l...                   0.0
#
#                                                                                \
# subcategory                                        Jackets Leggings Nightgown
# name
#  Chemise boutonnée à col en forme de chat              0.0      0.0       0.0
#  Chemise irrégulière oversize occasionnelle de ...     0.0      0.0       0.0
#  Chemisier ample imprimé sauvage simple boutonnage     0.0      0.0       0.0
#  Chemisier décontracté à manches longues et col...     0.0      0.0       0.0
#  Gradient Casual Sweat à manches longues pour l...     0.0      0.0       0.0
#
#                                                                  \
# subcategory                                        Robes Shorts
# name
#  Chemise boutonnée à col en forme de chat            0.0    0.0
#  Chemise irrégulière oversize occasionnelle de ...   0.0    0.0
#  Chemisier ample imprimé sauvage simple boutonnage   0.0    0.0
#  Chemisier décontracté à manches longues et col...   0.0    0.0
#  Gradient Casual Sweat à manches longues pour l...   0.0    0.0
#
#                                                                     \
# subcategory                                        Suits & Co-ords
# name
#  Chemise boutonnée à col en forme de chat                      0.0
#  Chemise irrégulière oversize occasionnelle de ...             0.0
#  Chemisier ample imprimé sauvage simple boutonnage             0.0
#  Chemisier décontracté à manches longues et col...             0.0
#  Gradient Casual Sweat à manches longues pour l...             0.0
#
#                                                                              \
# subcategory                                        Sun Protective Outerwear
# name
#  Chemise boutonnée à col en forme de chat                               0.0
#  Chemise irrégulière oversize occasionnelle de ...                      0.0
#  Chemisier ample imprimé sauvage simple boutonnage                      0.0
#  Chemisier décontracté à manches longues et col...                      0.0
#  Gradient Casual Sweat à manches longues pour l...                      0.0
#
#                                                                            \
# subcategory                                        Sweatershirts T-shirts
# name
#  Chemise boutonnée à col en forme de chat                    0.0      0.0
#  Chemise irrégulière oversize occasionnelle de ...           0.0      0.0
#  Chemisier ample imprimé sauvage simple boutonnage           0.0      0.0
#  Chemisier décontracté à manches longues et col...           0.0      0.0
#  Gradient Casual Sweat à manches longues pour l...           0.0      0.0
#
#
# subcategory                                        TOPS Tops
# name
#  Chemise boutonnée à col en forme de chat           0.0  0.0
#  Chemise irrégulière oversize occasionnelle de ...  0.0  0.0
#  Chemisier ample imprimé sauvage simple boutonnage  0.0  0.0
#  Chemisier décontracté à manches longues et col...  0.0  0.0
#  Gradient Casual Sweat à manches longues pour l...  0.0  0.0

# %%
likes_features_df.shape
# Out:
# (4583, 68)

# %%
from scipy.sparse import csr_matrix

likes_features_df_matrix = csr_matrix(likes_features_df.values)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model_women_knn = NearestNeighbors(metric='cosine', algorithm='brute')
model_women_knn.fit(likes_features_df_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
query_index = np.random.choice(likes_features_df.shape[0])
print(query_index)
# Out:
# 2108

# %%
likes_features_df.index
# Out:
# Index([' Chemise boutonnée à col en forme de chat ',
#        ' Chemise irrégulière oversize occasionnelle de couleur unie',
#        ' Chemisier ample imprimé sauvage simple boutonnage',
#        ' Chemisier décontracté à manches longues et col en V',
#        ' Gradient Casual Sweat à manches longues pour les femmes',
#        ' Jeans brodés fille à taille élastique',
#        ' Robe longue patchwork de couleur contrastée vintage',
#        ' Sweat à capuche avec cordon de couleur unie',
#        ' Sweat-shirt décontracté ample brodé',
#        ' Sweat-shirt à une épaule imprimé de lettres ',
#        ...
#        'Zebra - Chemisier à col en V imprimé',
#        'Zebra Blouse ample avec cordon de serrage',
#        'Zebra Blouse à épaules dénudées imprimée',
#        'Zipper Fly V-cou à manches courtes Blouses occasionnels',
#        'tricot chemisier patchwork imprimé floral',
#        'Élégante patchwork à carreaux lâche col rond robe trapèze pour les femmes ',
#        'Éléphant Cartoon T-shirt irrégulier',
#        'Épaissir le manteau de fourrure de revers solide',
#        'Épaissir les leggings slim en velours chaud et extensible ',
#        'Étoiles Imprimer Off-épaule Femmes T-shirts'],
#       dtype='object', name='name', length=4583)

# %%
# query_index = 0
# for i in range(likes_features_df.index.shape[0]):
#     if likes_features_df.index[i] == ' Gradient Casual Sweat à manches longues pour les femmes':
#         query_index = i
        
# query_index

# %%
likes_features_df.iloc[query_index, :]
# Out:
#                subcategory
# current_price  Blazers                      0.00
#                Blouses & Chemises          28.62
#                Chemises                     0.00
#                Denim & Jeans                0.00
#                Hoodies                      0.00
#                                            ...
# raw_price      Sun Protective Outerwear     0.00
#                Sweatershirts                0.00
#                T-shirts                     0.00
#                TOPS                         0.00
#                Tops                         0.00
# Name: Chemisier uni couleur unie, Length: 68, dtype: float64

# %%
distances, indices = model_women_knn.kneighbors(likes_features_df.iloc[query_index, :].values.reshape(1,-1), n_neighbors=11)

# %%
ls =[]
for i in range(0, len(distances.flatten())):
    if i == 0:
        print("Recommendations for {0}".format(likes_features_df.index[query_index]))
    else:
        print("{0}: {1}, with distance of {2}".format(i, likes_features_df.index[indices.flatten()[i]], distances.flatten()[i]))
        ls.append(likes_features_df.index[indices.flatten()[i]])
# Out:
# Recommendations for Chemisier uni couleur unie
# 1: Blouse à col en V et imprimé carré , with distance of 1.3111242647134702e-08
# 2: Chemisiers imprimés style folk, with distance of 2.9221529624923193e-06
# 3: Chemise de couleur unie à manches lanterne, with distance of 8.075592747069926e-06
# 4: Blouse ample en couleur pure pour femme, with distance of 1.951166523772585e-05
# 5: Chemisier boutonné brodé de fleurs, with distance of 2.357883490278212e-05
# 6: Chemisier patchwork rayé imprimé dessin animé, with distance of 2.7160891148736432e-05
# 7: Chemisier imprimé papillons, with distance of 3.209641647439199e-05
# 8: Blouse à manches longues imprimée à col droit, with distance of 3.5422858410294467e-05
# 9: Chemisier léopard à manches longues et col en V, with distance of 4.285794543112953e-05
# 10: Chemisier imprimé léopard à col en V, with distance of 4.456284262743804e-05

# %%
likes_features_df.index[indices.flatten()[7]]
# Out:
# 'Chemisier imprimé papillons'

# %%
ls
# Out:
# ['Blouse à col en V et imprimé carré ',
#  'Chemisiers imprimés style folk',
#  'Chemise de couleur unie à manches lanterne',
#  'Blouse ample en couleur pure pour femme',
#  'Chemisier boutonné brodé de fleurs',
#  'Chemisier patchwork rayé imprimé dessin animé',
#  'Chemisier imprimé papillons',
#  'Blouse à manches longues imprimée à col droit',
#  'Chemisier léopard à manches longues et col en V',
#  'Chemisier imprimé léopard à col en V']

# %%
new = data['name'].isin([likes_features_df.index[indices.flatten()[7]]])

# %%
new_ls = data['name'].isin(ls)

# %%
data[new_ls]
# Out:
#       category         subcategory  \
# 2649     women  Blouses & Chemises
# 3077     women  Blouses & Chemises
# 9838     women  Blouses & Chemises
# 10178    women  Blouses & Chemises
# 10915    women  Blouses & Chemises
# 11038    women  Blouses & Chemises
# 11388    women  Blouses & Chemises
# 12302    women  Blouses & Chemises
# 12696    women  Blouses & Chemises
# 13631    women  Blouses & Chemises
#
#                                                   name  current_price  \
# 2649                       Chemisier imprimé papillons          22.99
# 3077           Blouse ample en couleur pure pour femme          28.62
# 9838        Chemise de couleur unie à manches lanterne          29.64
# 10178             Chemisier imprimé léopard à col en V          20.20
# 10915               Chemisier boutonné brodé de fleurs          26.99
# 11038    Blouse à manches longues imprimée à col droit          31.30
# 11388              Blouse à col en V et imprimé carré           21.46
# 12302  Chemisier léopard à manches longues et col en V          15.99
# 12696    Chemisier patchwork rayé imprimé dessin animé          29.64
# 13631                   Chemisiers imprimés style folk          67.47
#
#        raw_price currency  discount  likes_count  is_new   brand brand_url  \
# 2649       44.88      USD        49          190   False     NaN       NaN
# 3077       55.99      USD        49          224   False  Celmia       NaN
# 9838       57.99      USD        49          234   False  ZANZEA       NaN
# 10178      39.46      USD        49          168   False  ZANZEA       NaN
# 10915      52.98      USD        49          223   False     NaN       NaN
# 11038      61.37      USD        49          260   False  ZANZEA       NaN
# 11388      41.99      USD        49          172   False     NaN       NaN
# 12302      28.99      USD        45          119   False     NaN       NaN
# 12696      57.99      USD        49          231   False     NaN       NaN
# 13631     132.01      USD        49          536   False     NaN       NaN
#
#               codCountry variation_0_color variation_1_color  \
# 2649   ID,MY,PH,SG,TH,VN             White              Pink
# 3077   ID,MY,PH,SG,TH,VN            Violet         Vin rouge
# 9838   ID,MY,PH,SG,TH,VN             Black             White
# 10178  ID,MY,PH,SG,TH,VN             Jaune               NaN
# 10915  ID,MY,PH,SG,TH,VN        Dark Green          Sky Blue
# 11038  ID,MY,PH,SG,TH,VN             Beige              Navy
# 11388  ID,MY,PH,SG,TH,VN         Colourful               NaN
# 12302  ID,MY,PH,SG,TH,VN              Pink             Green
# 12696  ID,MY,PH,SG,TH,VN             Black              Blue
# 13631  ID,MY,PH,SG,TH,VN            marron               NaN
#
#                                    variation_0_thumbnail  \
# 2649   https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 3077   https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 9838   https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10178  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10915  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 11038  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 11388  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 12302  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 12696  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 13631  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
#
#                                        variation_0_image  \
# 2649   https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3077   https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 9838   https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10178  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10915  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 11038  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 11388  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 12302  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 12696  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 13631  https://imgaz1.chiccdn.com/thumb/view/oaupload...
#
#                                    variation_1_thumbnail  \
# 2649   https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 3077   https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 9838   https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 10178                                                NaN
# 10915  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 11038  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 11388                                                NaN
# 12302  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 12696  https://imgaz1.chiccdn.com/thumb/list_grid/oau...
# 13631                                                NaN
#
#                                        variation_1_image  \
# 2649   https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3077   https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 9838   https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10178                                                NaN
# 10915  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 11038  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 11388                                                NaN
# 12302  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 12696  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 13631                                                NaN
#
#                                                image_url  \
# 2649   https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 3077   https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 9838   https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10178  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 10915  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 11038  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 11388  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 12302  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 12696  https://imgaz1.chiccdn.com/thumb/view/oaupload...
# 13631  https://imgaz1.chiccdn.com/thumb/view/oaupload...
#
#                                                      url       id      model
# 2649   https://fr.newchic.com/blouses-and-shirts-3689...  1657544  SKUE82717
# 3077   https://fr.newchic.com/blouses-and-shirts-3689...  1245163  SKU839643
# 9838   https://fr.newchic.com/blouses-and-shirts-3689...  1640000  SKUD04408
# 10178  https://fr.newchic.com/blouses-and-shirts-3689...  1502110  SKUB78125
# 10915  https://fr.newchic.com/blouses-and-shirts-3689...  1682343  SKUF28914
# 11038  https://fr.newchic.com/blouses-and-shirts-3689...  1368378  SKU942579
# 11388  https://fr.newchic.com/blouses-and-shirts-3689...  1588678  SKUD81753
# 12302  https://fr.newchic.com/blouses-and-shirts-3689...  1537495  SKUD04016
# 12696  https://fr.newchic.com/blouses-and-shirts-3689...  1580024  SKUD46482
# 13631  https://fr.newchic.com/blouses-and-shirts-3689...  1181971  SKU724219

# %%
import pickle

# %%
pickle.dump(model_women_knn, open('women_model.pkl', 'wb'))
